# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/atp_matches_train.csv")
df.head(10)
# Out:
#    Unnamed: 0 tourney_id tourney_name surface  draw_size tourney_level  \
# 0           0  1968-2029       Dublin   Grass       32.0             A
# 1           1  1968-2029       Dublin   Grass       32.0             A
# 2           2  1968-2029       Dublin   Grass       32.0             A
# 3           3  1968-2029       Dublin   Grass       32.0             A
# 4           4  1968-2029       Dublin   Grass       32.0             A
# 5           5  1968-2029       Dublin   Grass       32.0             A
# 6           6  1968-2029       Dublin   Grass       32.0             A
# 7           7  1968-2029       Dublin   Grass       32.0             A
# 8           8  1968-2029       Dublin   Grass       32.0             A
# 9           9  1968-2029       Dublin   Grass       32.0             A
#
#    tourney_date  match_num  winner_id  winner_seed  ... l_1stIn l_1stWon  \
# 0      19680708        270     112411          NaN  ...     NaN      NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194996 entries, 0 to 194995
# Data columns (total 50 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          194996 non-null  int64
#  1   tourney_id          194996 non-null  object
#  2   tourney_name        194996 non-null  object
#  3   surface             192006 non-null  object
#  4   draw_size           194161 non-null  float64
#  5   tourney_level       194996 non-null  object
#  6   tourney_date        194996 non-null  int64
#  7   match_num           194996 non-null  int64
#  8   winner_id           194996 non-null  int64
#  9   winner_seed         72220 non-null   float64
#  10  winner_entry        17220 non-null   object
#  11  winner_name         194996 non-null  object
#  12  winner_hand         194993 non-null  object
#  13  winner_ht           178366 non-null  float64
#  14  winner_ioc          194988 non-null  object
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0      draw_size  tourney_date      match_num  \
# count  194996.000000  194161.000000  1.949960e+05  194996.000000
# mean    97497.500000      53.244071  1.994190e+07      82.140567
# std     56290.640883      36.816886  1.613564e+05     113.867026
# min         0.000000       2.000000  1.967123e+07       1.000000
# 25%     48748.750000      32.000000  1.980071e+07      11.000000
# 50%     97497.500000      32.000000  1.993100e+07      26.000000
# 75%    146246.250000      64.000000  2.007123e+07     105.000000
# max    194995.000000     128.000000  2.024122e+07    1701.000000
#
#            winner_id   winner_seed      winner_ht     winner_age  \
# count  194996.000000  72220.000000  178366.000000  193687.000000
# mean   105319.932209      6.340612     184.573349      25.681538
# std     16049.732171      5.590401       6.784395       4.059004
# min    100001.000000      1.000000       3.000000      14.300000
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# tourney_id                 0
# tourney_name               0
# surface                 2990
# draw_size                835
# tourney_level              0
# tourney_date               0
# match_num                  0
# winner_id                  0
# winner_seed           122776
# winner_entry          177776
# winner_name                0
# winner_hand                3
# winner_ht              16630
# winner_ioc                 8
# winner_age              1309
# loser_id                   0
# loser_seed            158140
# loser_entry           165854
# loser_name                 0
# loser_hand                11
# loser_ht               29194
# loser_ioc                 72
# loser_age               4648
# score                      9
# best_of                    0
# round                      0
# minutes                99891
# w_ace                  96945
# w_df                   96946
# w_svpt                 96946
# w_1stIn                96946
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0            194996
# tourney_id              8463
# tourney_name            4189
# surface                    4
# draw_size                 19
# tourney_level              6
# tourney_date            3362
# match_num                578
# winner_id               4373
# winner_seed               34
# winner_entry              10
# winner_name             4384
# winner_hand                4
# winner_ht                 35
# winner_ioc               131
# winner_age               332
# loser_id                7413
# loser_seed                35
# loser_entry               11
# loser_name              7429
# loser_hand                 4
# loser_ht                  34
# loser_ioc                145
# loser_age                375
# score                  23589
# best_of                    3
# round                     10
# minutes                  327
# w_ace                     58
# w_df                      25
# w_svpt                   242
# w_1stIn                  165
# ...

# %%
df.sort_values(by="winner_rank", ascending=False).head()
# Out:
#         Unnamed: 0                         tourney_id  \
# 169165      169165                          2015-D069
# 163916      163916                          2013-D040
# 169169      169169                          2015-D067
# 169187      169187                          2015-D068
# 173553      173553  2017-M-DC-2017-G2-AO-M-PAK-IRI-01
#
#                        tourney_name surface  draw_size tourney_level  \
# 169165  Davis Cup G2 PO: IRI vs KUW    Clay        4.0             D
# 163916  Davis Cup G1 PO: DOM vs CHI    Hard        4.0             D
# 169169  Davis Cup G2 PO: LAT vs MAD    Clay        4.0             D
# 169187  Davis Cup G2 PO: SRI vs LIB    Clay        4.0             D
# 173553  Davis Cup G2 R1: PAK vs IRI    Hard        4.0             D
#
#         tourney_date  match_num  winner_id  winner_seed  ... l_1stIn l_1stWon  \
# 169165      20150717          1     105566          NaN  ...     NaN      NaN
# ...

# %%
numeric_df = df.select_dtypes(include=[float, int])
numeric_df.corr()
# Out:
#                     Unnamed: 0  draw_size  tourney_date  match_num  winner_id  \
# Unnamed: 0            1.000000   0.035779      0.998277   0.086077   0.331984
# draw_size             0.035779   1.000000      0.039244   0.206833   0.028912
# tourney_date          0.998277   0.039244      1.000000   0.117137   0.354013
# match_num             0.086077   0.206833      0.117137   1.000000   0.266848
# winner_id             0.331984   0.028912      0.354013   0.266848   1.000000
# winner_seed           0.169651   0.455010      0.169534   0.058610   0.080856
# winner_ht             0.262719   0.042882      0.264136   0.083466   0.099631
# winner_age            0.060694   0.024704      0.071617   0.117609  -0.141748
# loser_id              0.196859   0.021289      0.218832   0.289932   0.380968
# loser_seed            0.174399   0.579465      0.174519   0.102948   0.048652
# loser_ht              0.217155   0.030316      0.218083   0.085700   0.084606
# ...

# %%
plt.figure(figsize=(30, 20))
sns.heatmap(numeric_df.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
df.groupby("tourney_name")[df.select_dtypes(include=["number", "float"]).columns].mean()
# Out:
#                        Unnamed: 0  draw_size  tourney_date   match_num  \
# tourney_name
# ATP Rio de Janeiro  182355.000000  32.000000  2.020022e+07  285.000000
# Aberavon              4071.000000        NaN  1.968103e+07  114.000000
# Acapulco            158072.709763  31.704485  2.011813e+07  120.137203
# Adelaide             81625.225505  40.087092  1.989470e+07  102.443235
# Adelaide 1          187640.948276  32.000000  2.022545e+07  285.517241
# ...                           ...        ...           ...         ...
# Zell Am See WCT      58303.000000  32.000000  1.982071e+07   16.000000
# Zhuhai              186268.500000  32.000000  2.021092e+07  286.111111
# Zurich               38567.000000  32.000000  1.977123e+07   16.000000
# Zurich WCT           58272.000000  32.000000  1.982033e+07   16.000000
# s Hertogenbosch     152602.627876  31.707713  2.009913e+07   84.935047
#
#                         winner_id  winner_seed   winner_ht  winner_age  \
# tourney_name
# ...

# %%
df.groupby("tourney_level")[df.select_dtypes(include=["number", "float"]).columns].mean()
# Out:
#                   Unnamed: 0   draw_size  tourney_date   match_num  \
# tourney_level
# A               88768.940998   39.912708  1.991750e+07   83.937169
# D              110085.206897    3.968087  1.997456e+07    2.911427
# F              147059.065657    9.717172  2.008115e+07  157.764310
# G              107197.418274  125.051821  1.996867e+07  109.776918
# M              123248.128667   72.500062  2.001573e+07   87.619759
# O              193917.500000   64.000000  2.024073e+07  133.000000
#
#                    winner_id  winner_seed   winner_ht  winner_age  \
# tourney_level
# A              104622.008770     4.788697  184.244299   25.734838
# D              107218.202975          NaN  184.061658   24.782341
# F              114590.265993     3.736641  186.840067   25.111279
# G              105575.769437    10.255409  185.166775   25.876839
# M              107187.148459     8.790273  185.707355   25.735540
# O              154139.578125     6.589744  187.578125   27.170312
# ...

# %%
df.boxplot(figsize=(50, 40))
# Out:
# <Axes: >
